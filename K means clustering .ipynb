# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# let's create some data

from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=4, cluster_std=1.8, random_state=101)

# %%
data[0].shape #and you see: 200 data with 2 features
# Out:
# (200, 2)

# %%
sns.set()
plt.scatter(data[0][:,0], data[0][:,1])

# %%
#il grafico di sopra, plotta da data[0], tutte le rows e la prima colonna, vs data[0][:,1], la seconda colonna

# %%
data #come si vede è una matrice, con la prima colonna la tupla di dati (ho due features) e la seconda a "classificazione"
# Out:
# (array([[-6.42884095e+00,  1.01411174e+01],
#         [ 5.86867888e+00,  5.20110356e+00],
#         [-3.76109375e-01,  3.26427943e+00],
#         [ 2.16679181e+00,  9.56300522e+00],
#         [ 5.09508570e+00,  7.20752718e+00],
#         [-1.08788882e+01, -6.11318040e+00],
#         [ 2.03405554e+00,  9.76664755e+00],
#         [-1.71798771e+00,  1.41401140e+00],
#         [ 1.16911341e+00,  8.24556988e+00],
#         [-1.35185444e+00,  3.13245345e+00],
#         [-6.18548214e+00,  9.67406555e+00],
#         [-1.19856602e+00,  2.50408937e+00],
#         [ 2.90296863e+00,  7.91251003e+00],
#         [ 2.39250023e+00,  5.38173971e+00],
#         [-5.27545147e+00,  9.63836659e+00],
#         [-5.66814687e-01,  5.60262755e-02],
#         [ 5.97336628e+00,  5.87172022e+00],
#         [-2.31355268e+00,  5.23980092e-01],
#         [-1.01344756e+01, -3.43130837e+00],
#         [-4.54082629e+00,  1.13920174e+01],
#         [-1.04155833e+01, -5.67545836e+00],
# ...

# %%
data[0] #la tupla di dati,
# Out:
# array([[-6.42884095e+00,  1.01411174e+01],
#        [ 5.86867888e+00,  5.20110356e+00],
#        [-3.76109375e-01,  3.26427943e+00],
#        [ 2.16679181e+00,  9.56300522e+00],
#        [ 5.09508570e+00,  7.20752718e+00],
#        [-1.08788882e+01, -6.11318040e+00],
#        [ 2.03405554e+00,  9.76664755e+00],
#        [-1.71798771e+00,  1.41401140e+00],
#        [ 1.16911341e+00,  8.24556988e+00],
#        [-1.35185444e+00,  3.13245345e+00],
#        [-6.18548214e+00,  9.67406555e+00],
#        [-1.19856602e+00,  2.50408937e+00],
#        [ 2.90296863e+00,  7.91251003e+00],
#        [ 2.39250023e+00,  5.38173971e+00],
#        [-5.27545147e+00,  9.63836659e+00],
#        [-5.66814687e-01,  5.60262755e-02],
#        [ 5.97336628e+00,  5.87172022e+00],
#        [-2.31355268e+00,  5.23980092e-01],
#        [-1.01344756e+01, -3.43130837e+00],
#        [-4.54082629e+00,  1.13920174e+01],
#        [-1.04155833e+01, -5.67545836e+00],
#        [ 6.64796693e-01,  9.42304718e-02],
# ...

# %%
data[1] #looks like the clusters, e usiamo questo per fare il raggruppamento
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow', edgecolor='black')

# %%
data[0]
# Out:
# array([[-6.42884095e+00,  1.01411174e+01],
#        [ 5.86867888e+00,  5.20110356e+00],
#        [-3.76109375e-01,  3.26427943e+00],
#        [ 2.16679181e+00,  9.56300522e+00],
#        [ 5.09508570e+00,  7.20752718e+00],
#        [-1.08788882e+01, -6.11318040e+00],
#        [ 2.03405554e+00,  9.76664755e+00],
#        [-1.71798771e+00,  1.41401140e+00],
#        [ 1.16911341e+00,  8.24556988e+00],
#        [-1.35185444e+00,  3.13245345e+00],
#        [-6.18548214e+00,  9.67406555e+00],
#        [-1.19856602e+00,  2.50408937e+00],
#        [ 2.90296863e+00,  7.91251003e+00],
#        [ 2.39250023e+00,  5.38173971e+00],
#        [-5.27545147e+00,  9.63836659e+00],
#        [-5.66814687e-01,  5.60262755e-02],
#        [ 5.97336628e+00,  5.87172022e+00],
#        [-2.31355268e+00,  5.23980092e-01],
#        [-1.01344756e+01, -3.43130837e+00],
#        [-4.54082629e+00,  1.13920174e+01],
#        [-1.04155833e+01, -5.67545836e+00],
#        [ 6.64796693e-01,  9.42304718e-02],
# ...

# %%
data[0][:,0]
# Out:
# array([-6.42884095e+00,  5.86867888e+00, -3.76109375e-01,  2.16679181e+00,
#         5.09508570e+00, -1.08788882e+01,  2.03405554e+00, -1.71798771e+00,
#         1.16911341e+00, -1.35185444e+00, -6.18548214e+00, -1.19856602e+00,
#         2.90296863e+00,  2.39250023e+00, -5.27545147e+00, -5.66814687e-01,
#         5.97336628e+00, -2.31355268e+00, -1.01344756e+01, -4.54082629e+00,
#        -1.04155833e+01,  6.64796693e-01,  2.11460477e+00, -1.11790221e+01,
#        -6.63698251e+00, -7.67422005e+00, -7.98668260e+00,  1.27983684e+00,
#         3.54480244e+00,  4.03940181e+00, -2.88118898e+00, -9.11009911e+00,
#         5.26001172e+00,  2.05859724e+00, -1.71289834e+00, -5.40562319e+00,
#        -1.11995123e+01, -1.13753641e+01, -1.17821836e+01,  1.74815503e+00,
#        -9.00392334e+00, -2.86564584e+00, -1.42742293e+00, -3.10933432e+00,
#         2.71130095e-01,  8.21556561e-01, -4.11495481e+00,  1.55414928e+00,
# ...

# %%
A=[[1,2,3],[4,5,6]]

# %%
A[0]
# Out:
# [1, 2, 3]

# %%
A[0][0]
# Out:
# 1

# %%
B=np.array([[1,2,3],[4,5,6]])

# %%
B[0]
# Out:
# array([1, 2, 3])

# %%
B[:,1] #second column
# Out:
# array([2, 5])

# %%
B[0][1]
# Out:
# 2

# %%
B[0,1]
# Out:
# 2

# %%
sns.set()
plt.scatter(data[0][:,0], data[0][:,1])

# %%
plt.scatter(data[0][:,0], data[0][:,1], c=data[1], cmap='rainbow', edgecolor='black')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit(data[0])
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 3.71749226,  7.01388735],
#        [-9.46941837, -6.56081545],
#        [-4.13591321,  7.95389851],
#        [-0.0123077 ,  2.13407664]])

# %%
kmeans.labels_
# Out:
# array([2, 0, 3, 0, 0, 1, 0, 3, 0, 3, 2, 3, 0, 0, 2, 3, 0, 3, 1, 2, 1, 3,
#        3, 1, 2, 1, 1, 3, 0, 0, 2, 1, 0, 3, 3, 2, 1, 1, 1, 3, 1, 2, 2, 2,
#        3, 0, 2, 3, 1, 3, 3, 2, 0, 3, 1, 2, 3, 3, 2, 0, 1, 0, 1, 2, 0, 3,
#        1, 0, 0, 1, 0, 3, 1, 3, 1, 0, 0, 3, 2, 3, 3, 1, 0, 1, 3, 3, 3, 2,
#        3, 1, 1, 1, 1, 3, 3, 1, 0, 2, 1, 0, 3, 1, 3, 3, 0, 3, 1, 0, 1, 1,
#        0, 2, 2, 0, 1, 0, 2, 2, 0, 2, 3, 2, 3, 2, 3, 0, 2, 3, 1, 2, 2, 2,
#        3, 1, 1, 2, 0, 2, 0, 3, 1, 0, 1, 2, 2, 0, 3, 1, 2, 2, 2, 2, 3, 0,
#        3, 2, 0, 0, 0, 3, 0, 3, 3, 2, 1, 2, 3, 0, 2, 3, 0, 3, 2, 0, 3, 2,
#        0, 0, 1, 0, 2, 1, 1, 2, 1, 1, 1, 1, 1, 3, 1, 0, 0, 2, 1, 3, 0, 0,
#        1, 3])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
kmeans1 = KMeans(n_clusters = 6)
kmeans1.fit(data[0])
# Out:
# KMeans(n_clusters=6)

# %%
kmeans1.cluster_centers_
# Out:
# array([[ -0.35257338,   5.89020711],
#        [ -8.88174094,  -7.65668825],
#        [  4.3172263 ,   7.04477898],
#        [  0.14363806,   1.2030127 ],
#        [-10.51417824,  -4.61259714],
#        [ -4.64125855,   8.09404675]])

# %%
kmeans1.labels_
# Out:
# array([5, 2, 3, 2, 2, 4, 2, 3, 0, 3, 5, 3, 2, 2, 5, 3, 2, 3, 4, 5, 4, 3,
#        3, 1, 5, 1, 1, 3, 2, 2, 5, 1, 2, 3, 3, 5, 4, 4, 1, 3, 1, 5, 0, 5,
#        3, 0, 5, 3, 1, 0, 3, 5, 2, 3, 1, 0, 0, 3, 5, 2, 1, 0, 1, 0, 2, 3,
#        4, 2, 2, 1, 2, 0, 4, 0, 1, 2, 2, 3, 5, 3, 0, 1, 2, 1, 3, 3, 3, 5,
#        0, 4, 1, 1, 4, 0, 0, 1, 2, 5, 1, 2, 0, 4, 3, 3, 0, 0, 4, 2, 1, 1,
#        2, 5, 5, 2, 1, 2, 5, 5, 0, 0, 0, 5, 3, 5, 3, 2, 5, 3, 1, 0, 5, 5,
#        3, 1, 4, 5, 2, 0, 2, 3, 1, 2, 4, 0, 0, 2, 0, 1, 5, 5, 5, 5, 3, 2,
#        3, 5, 0, 2, 2, 3, 2, 3, 0, 5, 4, 5, 3, 2, 5, 3, 2, 3, 5, 0, 0, 5,
#        2, 0, 1, 0, 5, 1, 1, 5, 4, 1, 4, 1, 1, 3, 4, 2, 2, 5, 1, 0, 2, 2,
#        4, 3])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means 1')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans1.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
